# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the csv file into dataframe 'df'
df=pd.read_csv('C:\\Users\\user\\Downloads\\telecom_churn_data.csv',encoding='utf-8',low_memory=False)

# %%
df.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6     ...      sachet_3g_9  fb_user_6  \
# ...

# %%
df.columns
# Out:
# Index(['mobile_number', 'circle_id', 'loc_og_t2o_mou', 'std_og_t2o_mou',
#        'loc_ic_t2o_mou', 'last_date_of_month_6', 'last_date_of_month_7',
#        'last_date_of_month_8', 'last_date_of_month_9', 'arpu_6',
#        ...
#        'sachet_3g_9', 'fb_user_6', 'fb_user_7', 'fb_user_8', 'fb_user_9',
#        'aon', 'aug_vbc_3g', 'jul_vbc_3g', 'jun_vbc_3g', 'sep_vbc_3g'],
#       dtype='object', length=226)

# %%
#Information about the dataframe is shown.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Columns: 226 entries, mobile_number to sep_vbc_3g
# dtypes: float64(179), int64(35), object(12)
# memory usage: 167.8+ MB

# %%
df.shape
# Out:
# (99999, 226)

# %%
#Removing rows if there are any duplicates.
df.drop_duplicates(keep=False)

# %%
#Checking if the columns have all null values.
df.isnull().all()
# Out:
# mobile_number           False
# circle_id               False
# loc_og_t2o_mou          False
# std_og_t2o_mou          False
# loc_ic_t2o_mou          False
# last_date_of_month_6    False
# last_date_of_month_7    False
# last_date_of_month_8    False
# last_date_of_month_9    False
# arpu_6                  False
# arpu_7                  False
# arpu_8                  False
# arpu_9                  False
# onnet_mou_6             False
# onnet_mou_7             False
# onnet_mou_8             False
# onnet_mou_9             False
# offnet_mou_6            False
# offnet_mou_7            False
# offnet_mou_8            False
# offnet_mou_9            False
# roam_ic_mou_6           False
# roam_ic_mou_7           False
# roam_ic_mou_8           False
# roam_ic_mou_9           False
# roam_og_mou_6           False
# roam_og_mou_7           False
# roam_og_mou_8           False
# roam_og_mou_9           False
# loc_og_t2t_mou_6        False
#                         ...
# ...

# %%
#Removing columns if they consist of all null values.
df=df.dropna(axis=1,how='all')

# %%
df.shape
# Out:
# (99999, 226)

# %%
df.isnull().sum()
# Out:
# mobile_number               0
# circle_id                   0
# loc_og_t2o_mou           1018
# std_og_t2o_mou           1018
# loc_ic_t2o_mou           1018
# last_date_of_month_6        0
# last_date_of_month_7      601
# last_date_of_month_8     1100
# last_date_of_month_9     1659
# arpu_6                      0
# arpu_7                      0
# arpu_8                      0
# arpu_9                      0
# onnet_mou_6              3937
# onnet_mou_7              3859
# onnet_mou_8              5378
# onnet_mou_9              7745
# offnet_mou_6             3937
# offnet_mou_7             3859
# offnet_mou_8             5378
# offnet_mou_9             7745
# roam_ic_mou_6            3937
# roam_ic_mou_7            3859
# roam_ic_mou_8            5378
# roam_ic_mou_9            7745
# roam_og_mou_6            3937
# roam_og_mou_7            3859
# roam_og_mou_8            5378
# roam_og_mou_9            7745
# loc_og_t2t_mou_6         3937
#                         ...
# ...

# %%
# Checking the percentage of missing values
round(100*(df.isnull().sum()/len(df)), 2)
# Out:
# mobile_number            0.00
# circle_id                0.00
# loc_og_t2o_mou           1.02
# std_og_t2o_mou           1.02
# loc_ic_t2o_mou           1.02
# last_date_of_month_6     0.00
# last_date_of_month_7     0.60
# last_date_of_month_8     1.10
# last_date_of_month_9     1.66
# arpu_6                   0.00
# arpu_7                   0.00
# arpu_8                   0.00
# arpu_9                   0.00
# onnet_mou_6              3.94
# onnet_mou_7              3.86
# onnet_mou_8              5.38
# onnet_mou_9              7.75
# offnet_mou_6             3.94
# offnet_mou_7             3.86
# offnet_mou_8             5.38
# offnet_mou_9             7.75
# roam_ic_mou_6            3.94
# roam_ic_mou_7            3.86
# roam_ic_mou_8            5.38
# roam_ic_mou_9            7.75
# roam_og_mou_6            3.94
# roam_og_mou_7            3.86
# roam_og_mou_8            5.38
# roam_og_mou_9            7.75
# loc_og_t2t_mou_6         3.94
#                         ...
# ...

# %%
#Checking missing values along rows.
df.isnull().sum(axis=1)
# Out:
# 0         97
# 1         20
# 2         30
# 3         40
# 4         30
# 5         40
# 6         40
# 7         69
# 8         20
# 9         30
# 10        49
# 11        31
# 12        40
# 13        30
# 14        40
# 15        69
# 16        40
# 17        40
# 18        40
# 19        10
# 20        40
# 21        40
# 22        40
# 23        10
# 24        40
# 25        40
# 26        40
# 27        40
# 28        30
# 29        69
#         ...
# 99969     20
# 99970     10
# 99971     40
# 99972     30
# 99973     41
# 99974     40
# 99975     40
# 99976     40
# 99977     40
# 99978    162
# 99979     40
# 99980     10
# 99981     11
# 99982     10
# 99983     99
# 99984      0
# 99985     41
# 99986      0
# 99987     30
# 99988     10
# 99989     40
# 99990     30
# 99991     40
# 99992     40
# 99993    164
# 99994     40
# 99995     40
# 99996    118
# 99997      0
# 99998    120
# Length: 99999, dtype: int64

# %%
# Checking the percentage of missing values
round(100*(df.isnull().sum(axis=1)/len(df.columns)), 2)
# Out:
# 0        42.92
# 1         8.85
# 2        13.27
# 3        17.70
# 4        13.27
# 5        17.70
# 6        17.70
# 7        30.53
# 8         8.85
# 9        13.27
# 10       21.68
# 11       13.72
# 12       17.70
# 13       13.27
# 14       17.70
# 15       30.53
# 16       17.70
# 17       17.70
# 18       17.70
# 19        4.42
# 20       17.70
# 21       17.70
# 22       17.70
# 23        4.42
# 24       17.70
# 25       17.70
# 26       17.70
# 27       17.70
# 28       13.27
# 29       30.53
#          ...
# 99969     8.85
# 99970     4.42
# 99971    17.70
# 99972    13.27
# 99973    18.14
# 99974    17.70
# 99975    17.70
# 99976    17.70
# 99977    17.70
# 99978    71.68
# 99979    17.70
# 99980     4.42
# 99981     4.87
# 99982     4.42
# 99983    43.81
# 99984     0.00
# 99985    18.14
# 99986     0.00
# 99987    13.27
# 99988     4.42
# 99989    17.70
# 99990    13.27
# 99991    17.70
# 99992    17.70
# 99993    72.57
# 99994    17.70
# 99995    17.70
# ...

# %%
#Removing rows if they consist of all null values.
df=df.dropna(how='all')
df.shape
# Out:
# (99999, 226)

# %%
df.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6     ...      sachet_3g_9  fb_user_6  \
# ...

# %%
df.groupby('last_date_of_month_6').count()
# Out:
#                       mobile_number  circle_id  loc_og_t2o_mou  \
# last_date_of_month_6
# 6/30/2014                     99999      99999           98981
#
#                       std_og_t2o_mou  loc_ic_t2o_mou  last_date_of_month_7  \
# last_date_of_month_6
# 6/30/2014                      98981           98981                 99398
#
#                       last_date_of_month_8  last_date_of_month_9  arpu_6  \
# last_date_of_month_6
# 6/30/2014                            98899                 98340   99999
#
#                       arpu_7     ...      sachet_3g_9  fb_user_6  fb_user_7  \
# last_date_of_month_6             ...
# 6/30/2014              99999     ...            99999      25153      25571
#
#                       fb_user_8  fb_user_9    aon  aug_vbc_3g  jul_vbc_3g  \
# last_date_of_month_6
# 6/30/2014                 26339      25922  99999       99999       99999
#
#                       jun_vbc_3g  sep_vbc_3g
# last_date_of_month_6
# ...

# %%
df.groupby('last_date_of_month_7').count()
# Out:
#                       mobile_number  circle_id  loc_og_t2o_mou  \
# last_date_of_month_7
# 7/31/2014                     99398      99398           98703
#
#                       std_og_t2o_mou  loc_ic_t2o_mou  last_date_of_month_6  \
# last_date_of_month_7
# 7/31/2014                      98703           98703                 99398
#
#                       last_date_of_month_8  last_date_of_month_9  arpu_6  \
# last_date_of_month_7
# 7/31/2014                            98834                 98340   99398
#
#                       arpu_7     ...      sachet_3g_9  fb_user_6  fb_user_7  \
# last_date_of_month_7             ...
# 7/31/2014              99398     ...            99398      25085      25571
#
#                       fb_user_8  fb_user_9    aon  aug_vbc_3g  jul_vbc_3g  \
# last_date_of_month_7
# 7/31/2014                 26339      25922  99398       99398       99398
#
#                       jun_vbc_3g  sep_vbc_3g
# last_date_of_month_7
# ...

# %%
df.groupby('last_date_of_month_8').count()
# Out:
#                       mobile_number  circle_id  loc_og_t2o_mou  \
# last_date_of_month_8
# 8/31/2014                     98899      98899           98230
#
#                       std_og_t2o_mou  loc_ic_t2o_mou  last_date_of_month_6  \
# last_date_of_month_8
# 8/31/2014                      98230           98230                 98899
#
#                       last_date_of_month_7  last_date_of_month_9  arpu_6  \
# last_date_of_month_8
# 8/31/2014                            98834                 98340   98899
#
#                       arpu_7     ...      sachet_3g_9  fb_user_6  fb_user_7  \
# last_date_of_month_8             ...
# 8/31/2014              98899     ...            98899      24911      25510
#
#                       fb_user_8  fb_user_9    aon  aug_vbc_3g  jul_vbc_3g  \
# last_date_of_month_8
# 8/31/2014                 26339      25922  98899       98899       98899
#
#                       jun_vbc_3g  sep_vbc_3g
# last_date_of_month_8
# ...

# %%
df.groupby('last_date_of_month_9').count()
# Out:
#                       mobile_number  circle_id  loc_og_t2o_mou  \
# last_date_of_month_9
# 9/30/2014                     98340      98340           97728
#
#                       std_og_t2o_mou  loc_ic_t2o_mou  last_date_of_month_6  \
# last_date_of_month_9
# 9/30/2014                      97728           97728                 98340
#
#                       last_date_of_month_7  last_date_of_month_8  arpu_6  \
# last_date_of_month_9
# 9/30/2014                            98340                 98340   98340
#
#                       arpu_7     ...      sachet_3g_9  fb_user_6  fb_user_7  \
# last_date_of_month_9             ...
# 9/30/2014              98340     ...            98340      24742      25341
#
#                       fb_user_8  fb_user_9    aon  aug_vbc_3g  jul_vbc_3g  \
# last_date_of_month_9
# 9/30/2014                 26267      25922  98340       98340       98340
#
#                       jun_vbc_3g  sep_vbc_3g
# last_date_of_month_9
# ...

# %%
#Since these columns consist of only one value, these can be removed.
del df['last_date_of_month_6']
del df['last_date_of_month_7']
del df['last_date_of_month_8']
del df['last_date_of_month_9']

# %%
df.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
#
#     arpu_6   arpu_7   arpu_8   arpu_9  onnet_mou_6     ...      sachet_3g_9  \
# 0  197.385  214.816  213.803   21.100          NaN     ...                0
# 1   34.047  355.074  268.321   86.285        24.11     ...                0
# 2  167.690  189.058  210.226  290.714        11.54     ...                0
# 3  221.338  251.102  508.054  389.500        99.91     ...                0
# 4  261.636  309.876  238.174  163.426        50.31     ...                0
#
# ...

# %%
df.describe()
# Out:
#        mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# count   9.999900e+04    99999.0         98981.0         98981.0
# mean    7.001207e+09      109.0             0.0             0.0
# std     6.956694e+05        0.0             0.0             0.0
# min     7.000000e+09      109.0             0.0             0.0
# 25%     7.000606e+09      109.0             0.0             0.0
# 50%     7.001205e+09      109.0             0.0             0.0
# 75%     7.001812e+09      109.0             0.0             0.0
# max     7.002411e+09      109.0             0.0             0.0
#
#        loc_ic_t2o_mou        arpu_6        arpu_7        arpu_8        arpu_9  \
# count         98981.0  99999.000000  99999.000000  99999.000000  99999.000000
# mean              0.0    282.987358    278.536648    279.154731    261.645069
# std               0.0    328.439770    338.156291    344.474791    341.998630
# ...

# %%
#Circle id is having only one value, hence it can be removed
del df['circle_id']

# %%
df.columns
# Out:
# Index(['mobile_number', 'loc_og_t2o_mou', 'std_og_t2o_mou', 'loc_ic_t2o_mou',
#        'arpu_6', 'arpu_7', 'arpu_8', 'arpu_9', 'onnet_mou_6', 'onnet_mou_7',
#        ...
#        'sachet_3g_9', 'fb_user_6', 'fb_user_7', 'fb_user_8', 'fb_user_9',
#        'aon', 'aug_vbc_3g', 'jul_vbc_3g', 'jun_vbc_3g', 'sep_vbc_3g'],
#       dtype='object', length=221)

# %%
#Calculating average redcharge amount
def avg(x):
    return (x['total_rech_amt_6']+x['total_rech_amt_7'])/2

# %%
df['Average_amount']=df.apply(avg,axis=1)

# %%
#Calculating min avg recharge amount that helps us fing the type of customers
percentile=np.percentile(df['Average_amount'],70)
print(percentile)
# Out:
# 368.5

# %%
#Defining customers ino high valued and not high valued
def func(x):
    if(x['Average_amount']>=percentile):
        return 'High Value'
    else:
        return 'Not High Value'

# %%
df['Customers']=df.apply(func,axis=1)

# %%
df['Customers'].head()
# Out:
# 0    Not High Value
# 1    Not High Value
# 2    Not High Value
# 3    Not High Value
# 4    Not High Value
# Name: Customers, dtype: object

# %%
df=df[df['Customers']=='High Value']

# %%
df.shape
# Out:
# (30011, 223)

# %%
df['total_ic_mou_9'].head()
# Out:
# 7       0.00
# 8      34.91
# 13    631.86
# 16    334.56
# 17     87.13
# Name: total_ic_mou_9, dtype: float64

# %%
df['total_og_mou_9'].head()
# Out:
# 7       0.00
# 8     142.18
# 13    446.09
# 16    255.74
# 17    631.08
# Name: total_og_mou_9, dtype: float64

# %%
df['vol_2g_mb_9'].head()
# Out:
# 7     0.0
# 8     0.0
# 13    0.0
# 16    0.0
# 17    0.0
# Name: vol_2g_mb_9, dtype: float64

# %%
df['vol_3g_mb_9'].head()
# Out:
# 7     0.0
# 8     0.0
# 13    0.0
# 16    0.0
# 17    0.0
# Name: vol_3g_mb_9, dtype: float64

# %%
#Calculating churn values of every customer.
def churnfunc(x):
    if(x['total_ic_mou_9']==0.0 and x['total_og_mou_9']==0.0 and x['vol_2g_mb_9']==0.0 and x['vol_3g_mb_9']==0.0):
        return 1
    else:
        return 0

# %%
df['Churn']=df.apply(churnfunc,axis=1)

# %%
df['Churn'].head()
# Out:
# 7     1
# 8     0
# 13    0
# 16    0
# 17    0
# Name: Churn, dtype: int64

# %%
#Removing columns as they're no longer required.
del df['total_ic_mou_9']
del df['total_og_mou_9']
del df['vol_3g_mb_9']
del df['vol_2g_mb_9']

# %%
df.describe()
# Out:
#        mobile_number  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# count   3.001100e+04         29897.0         29897.0         29897.0
# mean    7.001223e+09             0.0             0.0             0.0
# std     6.846405e+05             0.0             0.0             0.0
# min     7.000000e+09             0.0             0.0             0.0
# 25%     7.000641e+09             0.0             0.0             0.0
# 50%     7.001232e+09             0.0             0.0             0.0
# 75%     7.001814e+09             0.0             0.0             0.0
# max     7.002411e+09             0.0             0.0             0.0
#
#              arpu_6        arpu_7        arpu_8        arpu_9   onnet_mou_6  \
# count  30011.000000  30011.000000  30011.000000  30011.000000  29695.000000
# mean     587.284404    589.135427    534.857433    488.656197    299.184718
# std      442.722413    462.897814    492.259586    496.486834    462.202367
# ...

# %%
#REmoving columns ending with _9
delete_col = [col for col in df if col.endswith('_9')]

# %%
delete_col
# Out:
# ['arpu_9',
#  'onnet_mou_9',
#  'offnet_mou_9',
#  'roam_ic_mou_9',
#  'roam_og_mou_9',
#  'loc_og_t2t_mou_9',
#  'loc_og_t2m_mou_9',
#  'loc_og_t2f_mou_9',
#  'loc_og_t2c_mou_9',
#  'loc_og_mou_9',
#  'std_og_t2t_mou_9',
#  'std_og_t2m_mou_9',
#  'std_og_t2f_mou_9',
#  'std_og_t2c_mou_9',
#  'std_og_mou_9',
#  'isd_og_mou_9',
#  'spl_og_mou_9',
#  'og_others_9',
#  'loc_ic_t2t_mou_9',
#  'loc_ic_t2m_mou_9',
#  'loc_ic_t2f_mou_9',
#  'loc_ic_mou_9',
#  'std_ic_t2t_mou_9',
#  'std_ic_t2m_mou_9',
#  'std_ic_t2f_mou_9',
#  'std_ic_t2o_mou_9',
#  'std_ic_mou_9',
#  'spl_ic_mou_9',
#  'isd_ic_mou_9',
#  'ic_others_9',
#  'total_rech_num_9',
#  'total_rech_amt_9',
#  'max_rech_amt_9',
#  'date_of_last_rech_9',
#  'last_day_rch_amt_9',
#  'date_of_last_rech_data_9',
#  'total_rech_data_9',
#  'max_rech_data_9',
#  'count_rech_2g_9',
#  'count_rech_3g_9',
#  'av_rech_amt_data_9',
#  'arpu_3g_9',
#  'arpu_2g_9',
#  'night_pck_user_9',
#  'monthly_2g_9',
#  'sachet_2g_9',
#  'monthly_3g_9',
# ...

# %%
df=df.drop(df[delete_col],axis=1)

# %%
df.shape
# Out:
# (30011, 171)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30011 entries, 7 to 99997
# Columns: 171 entries, mobile_number to Churn
# dtypes: float64(137), int64(27), object(7)
# memory usage: 38.6+ MB

# %%
df.columns
# Out:
# Index(['mobile_number', 'loc_og_t2o_mou', 'std_og_t2o_mou', 'loc_ic_t2o_mou',
#        'arpu_6', 'arpu_7', 'arpu_8', 'onnet_mou_6', 'onnet_mou_7',
#        'onnet_mou_8',
#        ...
#        'fb_user_7', 'fb_user_8', 'aon', 'aug_vbc_3g', 'jul_vbc_3g',
#        'jun_vbc_3g', 'sep_vbc_3g', 'Average_amount', 'Customers', 'Churn'],
#       dtype='object', length=171)

# %%
df.describe()
# Out:
#        mobile_number  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# count   3.001100e+04         29897.0         29897.0         29897.0
# mean    7.001223e+09             0.0             0.0             0.0
# std     6.846405e+05             0.0             0.0             0.0
# min     7.000000e+09             0.0             0.0             0.0
# 25%     7.000641e+09             0.0             0.0             0.0
# 50%     7.001232e+09             0.0             0.0             0.0
# 75%     7.001814e+09             0.0             0.0             0.0
# max     7.002411e+09             0.0             0.0             0.0
#
#              arpu_6        arpu_7        arpu_8   onnet_mou_6   onnet_mou_7  \
# count  30011.000000  30011.000000  30011.000000  29695.000000  29708.000000
# mean     587.284404    589.135427    534.857433    299.184718    307.447285
# std      442.722413    462.897814    492.259586    462.202367    483.244786
# ...

# %%
df.isnull().any()
# Out:
# mobile_number       False
# loc_og_t2o_mou       True
# std_og_t2o_mou       True
# loc_ic_t2o_mou       True
# arpu_6              False
# arpu_7              False
# arpu_8              False
# onnet_mou_6          True
# onnet_mou_7          True
# onnet_mou_8          True
# offnet_mou_6         True
# offnet_mou_7         True
# offnet_mou_8         True
# roam_ic_mou_6        True
# roam_ic_mou_7        True
# roam_ic_mou_8        True
# roam_og_mou_6        True
# roam_og_mou_7        True
# roam_og_mou_8        True
# loc_og_t2t_mou_6     True
# loc_og_t2t_mou_7     True
# loc_og_t2t_mou_8     True
# loc_og_t2m_mou_6     True
# loc_og_t2m_mou_7     True
# loc_og_t2m_mou_8     True
# loc_og_t2f_mou_6     True
# loc_og_t2f_mou_7     True
# loc_og_t2f_mou_8     True
# loc_og_t2c_mou_6     True
# loc_og_t2c_mou_7     True
#                     ...
# arpu_3g_8            True
# arpu_2g_6            True
# arpu_2g_7            True
# arpu_2g_8            True
# ...

# %%
df.isnull().sum()
# Out:
# mobile_number           0
# loc_og_t2o_mou        114
# std_og_t2o_mou        114
# loc_ic_t2o_mou        114
# arpu_6                  0
# arpu_7                  0
# arpu_8                  0
# onnet_mou_6           316
# onnet_mou_7           303
# onnet_mou_8           938
# offnet_mou_6          316
# offnet_mou_7          303
# offnet_mou_8          938
# roam_ic_mou_6         316
# roam_ic_mou_7         303
# roam_ic_mou_8         938
# roam_og_mou_6         316
# roam_og_mou_7         303
# roam_og_mou_8         938
# loc_og_t2t_mou_6      316
# loc_og_t2t_mou_7      303
# loc_og_t2t_mou_8      938
# loc_og_t2m_mou_6      316
# loc_og_t2m_mou_7      303
# loc_og_t2m_mou_8      938
# loc_og_t2f_mou_6      316
# loc_og_t2f_mou_7      303
# loc_og_t2f_mou_8      938
# loc_og_t2c_mou_6      316
# loc_og_t2c_mou_7      303
#                     ...
# arpu_3g_8           18257
# arpu_2g_6           18614
# arpu_2g_7           18349
# arpu_2g_8           18257
# ...

# %%
# Checking the percentage of missing values
round(100*(df.isnull().sum()/len(df)), 2)
# Out:
# mobile_number        0.00
# loc_og_t2o_mou       0.38
# std_og_t2o_mou       0.38
# loc_ic_t2o_mou       0.38
# arpu_6               0.00
# arpu_7               0.00
# arpu_8               0.00
# onnet_mou_6          1.05
# onnet_mou_7          1.01
# onnet_mou_8          3.13
# offnet_mou_6         1.05
# offnet_mou_7         1.01
# offnet_mou_8         3.13
# roam_ic_mou_6        1.05
# roam_ic_mou_7        1.01
# roam_ic_mou_8        3.13
# roam_og_mou_6        1.05
# roam_og_mou_7        1.01
# roam_og_mou_8        3.13
# loc_og_t2t_mou_6     1.05
# loc_og_t2t_mou_7     1.01
# loc_og_t2t_mou_8     3.13
# loc_og_t2m_mou_6     1.05
# loc_og_t2m_mou_7     1.01
# loc_og_t2m_mou_8     3.13
# loc_og_t2f_mou_6     1.05
# loc_og_t2f_mou_7     1.01
# loc_og_t2f_mou_8     3.13
# loc_og_t2c_mou_6     1.05
# loc_og_t2c_mou_7     1.01
#                     ...
# arpu_3g_8           60.83
# arpu_2g_6           62.02
# arpu_2g_7           61.14
# arpu_2g_8           60.83
# ...

# %%
frac=len(df)*0.5
frac
# Out:
# 15005.5

# %%
#Removing columns having greater than 50% null values.
df=df.dropna(thresh=frac,axis=1)

# %%
df.shape
# Out:
# (30011, 141)

# %%
df.isnull().sum()
# Out:
# mobile_number            0
# loc_og_t2o_mou         114
# std_og_t2o_mou         114
# loc_ic_t2o_mou         114
# arpu_6                   0
# arpu_7                   0
# arpu_8                   0
# onnet_mou_6            316
# onnet_mou_7            303
# onnet_mou_8            938
# offnet_mou_6           316
# offnet_mou_7           303
# offnet_mou_8           938
# roam_ic_mou_6          316
# roam_ic_mou_7          303
# roam_ic_mou_8          938
# roam_og_mou_6          316
# roam_og_mou_7          303
# roam_og_mou_8          938
# loc_og_t2t_mou_6       316
# loc_og_t2t_mou_7       303
# loc_og_t2t_mou_8       938
# loc_og_t2m_mou_6       316
# loc_og_t2m_mou_7       303
# loc_og_t2m_mou_8       938
# loc_og_t2f_mou_6       316
# loc_og_t2f_mou_7       303
# loc_og_t2f_mou_8       938
# loc_og_t2c_mou_6       316
# loc_og_t2c_mou_7       303
#                       ...
# date_of_last_rech_8    594
# last_day_rch_amt_6       0
# last_day_rch_amt_7       0
# ...

# %%
df.isnull().sum(axis=1)
# Out:
# 7         0
# 8         0
# 13        0
# 16        0
# 17        0
# 21        0
# 24        0
# 33        0
# 38        0
# 41        0
# 48        0
# 53        0
# 56        0
# 57        0
# 60        0
# 61        0
# 69        0
# 73        0
# 74        0
# 77       29
# 87        0
# 92        0
# 96        0
# 97        0
# 101       0
# 102       0
# 103       0
# 105       0
# 111      29
# 115       0
#          ..
# 99887     0
# 99893     0
# 99896     0
# 99899     0
# 99902     0
# 99904     0
# 99921     0
# 99922     0
# 99923     0
# 99924     0
# 99925     0
# 99927     0
# 99929     0
# 99931     0
# 99932     0
# 99935     0
# 99937     0
# 99939     0
# 99941     0
# 99943     0
# 99957     0
# 99959     0
# 99961     0
# 99963     0
# 99965     0
# 99970     0
# 99974     0
# 99986     0
# 99988     0
# 99997     0
# Length: 30011, dtype: int64

# %%
#Replacing every null value with median
df=df.fillna(df.median())

# %%
#CHecking if the columns have any null values.
df.isnull().sum()
# Out:
# mobile_number            0
# loc_og_t2o_mou           0
# std_og_t2o_mou           0
# loc_ic_t2o_mou           0
# arpu_6                   0
# arpu_7                   0
# arpu_8                   0
# onnet_mou_6              0
# onnet_mou_7              0
# onnet_mou_8              0
# offnet_mou_6             0
# offnet_mou_7             0
# offnet_mou_8             0
# roam_ic_mou_6            0
# roam_ic_mou_7            0
# roam_ic_mou_8            0
# roam_og_mou_6            0
# roam_og_mou_7            0
# roam_og_mou_8            0
# loc_og_t2t_mou_6         0
# loc_og_t2t_mou_7         0
# loc_og_t2t_mou_8         0
# loc_og_t2m_mou_6         0
# loc_og_t2m_mou_7         0
# loc_og_t2m_mou_8         0
# loc_og_t2f_mou_6         0
# loc_og_t2f_mou_7         0
# loc_og_t2f_mou_8         0
# loc_og_t2c_mou_6         0
# loc_og_t2c_mou_7         0
#                       ...
# date_of_last_rech_8    594
# last_day_rch_amt_6       0
# last_day_rch_amt_7       0
# ...

# %%
df.isnull().sum(axis=1)
# Out:
# 7        0
# 8        0
# 13       0
# 16       0
# 17       0
# 21       0
# 24       0
# 33       0
# 38       0
# 41       0
# 48       0
# 53       0
# 56       0
# 57       0
# 60       0
# 61       0
# 69       0
# 73       0
# 74       0
# 77       0
# 87       0
# 92       0
# 96       0
# 97       0
# 101      0
# 102      0
# 103      0
# 105      0
# 111      0
# 115      0
#         ..
# 99887    0
# 99893    0
# 99896    0
# 99899    0
# 99902    0
# 99904    0
# 99921    0
# 99922    0
# 99923    0
# 99924    0
# 99925    0
# 99927    0
# 99929    0
# 99931    0
# 99932    0
# 99935    0
# 99937    0
# 99939    0
# 99941    0
# 99943    0
# 99957    0
# 99959    0
# 99961    0
# 99963    0
# 99965    0
# 99970    0
# 99974    0
# 99986    0
# 99988    0
# 99997    0
# Length: 30011, dtype: int64

# %%
#Seeing Churn percentage,to see how many have churned.
churn = (sum(df['Churn'])/len(df))*100
churn
# Out:
# 8.64016527273333

# %%
df.head()
# Out:
#     mobile_number  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou    arpu_6  \
# 7      7000701601             0.0             0.0             0.0  1069.180
# 8      7001524846             0.0             0.0             0.0   378.721
# 13     7002191713             0.0             0.0             0.0   492.846
# 16     7000875565             0.0             0.0             0.0   430.975
# 17     7000187447             0.0             0.0             0.0   690.008
#
#       arpu_7    arpu_8  onnet_mou_6  onnet_mou_7  onnet_mou_8  ...    \
# 7   1349.850  3171.480        57.84        54.68        52.29  ...
# 8    492.223   137.362       413.69       351.03        35.08  ...
# 13   205.671   593.260       501.76       108.39       534.24  ...
# 16   299.869   187.894        50.51        74.01        70.61  ...
# 17    18.980    25.499      1185.91         9.28         7.79  ...
#
#     sachet_3g_7  sachet_3g_8   aon  aug_vbc_3g  jul_vbc_3g  jun_vbc_3g  \
# ...

# %%
df.describe()
# Out:
#        mobile_number  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# count   3.001100e+04         30011.0         30011.0         30011.0
# mean    7.001223e+09             0.0             0.0             0.0
# std     6.846405e+05             0.0             0.0             0.0
# min     7.000000e+09             0.0             0.0             0.0
# 25%     7.000641e+09             0.0             0.0             0.0
# 50%     7.001232e+09             0.0             0.0             0.0
# 75%     7.001814e+09             0.0             0.0             0.0
# max     7.002411e+09             0.0             0.0             0.0
#
#              arpu_6        arpu_7        arpu_8   onnet_mou_6   onnet_mou_7  \
# count  30011.000000  30011.000000  30011.000000  30011.000000  30011.000000
# mean     587.284404    589.135427    534.857433    297.385708    305.635027
# std      442.722413    462.897814    492.259586    460.093114    481.133789
# ...

# %%
#Deleting all categorical variables
del df['date_of_last_rech_6']
del df['date_of_last_rech_7']
del df['date_of_last_rech_8']
del df['Customers']
del df['mobile_number']

# %%
df.describe()
# Out:
#        loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou        arpu_6  \
# count         30011.0         30011.0         30011.0  30011.000000
# mean              0.0             0.0             0.0    587.284404
# std               0.0             0.0             0.0    442.722413
# min               0.0             0.0             0.0  -2258.709000
# 25%               0.0             0.0             0.0    364.161000
# 50%               0.0             0.0             0.0    495.682000
# 75%               0.0             0.0             0.0    703.922000
# max               0.0             0.0             0.0  27731.088000
#
#              arpu_7        arpu_8   onnet_mou_6   onnet_mou_7   onnet_mou_8  \
# count  30011.000000  30011.000000  30011.000000  30011.000000  30011.000000
# mean     589.135427    534.857433    297.385708    305.635027    270.922215
# std      462.897814    492.259586    460.093114    481.133789    465.019618
# ...

# %%
#We have removed every categorical variables, now we have only numeric variables
df.loc[:, df.dtypes == object]
# Out:
# Empty DataFrame
# Columns: []
# Index: [7, 8, 13, 16, 17, 21, 24, 33, 38, 41, 48, 53, 56, 57, 60, 61, 69, 73, 74, 77, 87, 92, 96, 97, 101, 102, 103, 105, 111, 115, 122, 124, 131, 133, 134, 143, 146, 147, 149, 154, 157, 158, 165, 170, 171, 173, 175, 176, 177, 184, 185, 188, 191, 195, 199, 203, 204, 206, 208, 213, 218, 223, 225, 226, 235, 241, 244, 245, 246, 252, 253, 255, 256, 259, 264, 266, 270, 274, 278, 281, 283, 284, 290, 292, 293, 294, 295, 301, 302, 304, 310, 319, 320, 321, 333, 337, 339, 345, 346, 356, ...]
#
# [30011 rows x 0 columns]

# %%
from sklearn.model_selection import train_test_split

# Putting feature variable to X
X = df.drop(['Churn'],axis=1)

# Putting response variable to y
y = df['Churn']

y.head()
# Out:
# 7     1
# 8     0
# 13    0
# 16    0
# 17    0
# Name: Churn, dtype: int64

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7,test_size=0.3,random_state=100)

# %%
X_train.shape
# Out:
# (21007, 135)

# %%
X.isnull().sum()
# Out:
# loc_og_t2o_mou        0
# std_og_t2o_mou        0
# loc_ic_t2o_mou        0
# arpu_6                0
# arpu_7                0
# arpu_8                0
# onnet_mou_6           0
# onnet_mou_7           0
# onnet_mou_8           0
# offnet_mou_6          0
# offnet_mou_7          0
# offnet_mou_8          0
# roam_ic_mou_6         0
# roam_ic_mou_7         0
# roam_ic_mou_8         0
# roam_og_mou_6         0
# roam_og_mou_7         0
# roam_og_mou_8         0
# loc_og_t2t_mou_6      0
# loc_og_t2t_mou_7      0
# loc_og_t2t_mou_8      0
# loc_og_t2m_mou_6      0
# loc_og_t2m_mou_7      0
# loc_og_t2m_mou_8      0
# loc_og_t2f_mou_6      0
# loc_og_t2f_mou_7      0
# loc_og_t2f_mou_8      0
# loc_og_t2c_mou_6      0
# loc_og_t2c_mou_7      0
# loc_og_t2c_mou_8      0
#                      ..
# max_rech_amt_6        0
# max_rech_amt_7        0
# max_rech_amt_8        0
# last_day_rch_amt_6    0
# last_day_rch_amt_7    0
# last_day_rch_amt_8    0
# vol_2g_mb_6           0
# ...

# %%
#Improting the PCA module
from sklearn.decomposition import PCA
pca = PCA(svd_solver='randomized', random_state=42)

# %%
#Doing the PCA on the train data
pca.fit(X_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=42,
#   svd_solver='randomized', tol=0.0, whiten=False)

# %%
pca.components_
# Out:
# array([[  9.79901464e-17,   0.00000000e+00,   8.32667268e-17, ...,
#          -3.38289844e-02,  -5.45617096e-04,   1.42359997e-01],
#        [  1.97024637e-17,  -5.55111512e-17,  -3.33066907e-16, ...,
#           1.67923208e-01,   5.40224777e-03,   1.53747454e-01],
#        [ -6.59940552e-18,   1.94289029e-16,  -3.33066907e-16, ...,
#          -3.75384840e-02,   5.50217897e-04,   9.89619334e-02],
#        ...,
#        [ -0.00000000e+00,  -4.47253571e-02,  -6.47597978e-02, ...,
#           5.20417043e-18,  -1.79435460e-17,  -3.74102777e-04],
#        [ -1.00000000e+00,   8.62029812e-23,   8.40230339e-24, ...,
#           1.69191778e-16,  -1.90682425e-14,   1.85639099e-16],
#        [ -0.00000000e+00,  -2.93363169e-02,   3.52936763e-02, ...,
#          -2.60208521e-18,   2.36212417e-15,  -4.94965114e-01]])

# %%
#From pca components we can see which variables affect the churn most
colnames = list(X_train.columns)
pcs_df = pd.DataFrame({'PC1':pca.components_[0],'PC2':pca.components_[1], 'Feature':colnames})
pcs_df.sort_values(ascending=False,by=['PC1','PC2'])
# Out:
#               Feature       PC1       PC2
# 58     total_og_mou_7  0.352327  0.010681
# 59     total_og_mou_8  0.330511  0.038572
# 46       std_og_mou_7  0.305819 -0.036340
# 47       std_og_mou_8  0.283607 -0.013709
# 57     total_og_mou_6  0.283171 -0.004369
# 45       std_og_mou_6  0.248531 -0.047589
# 10       offnet_mou_7  0.179238  0.025061
# 7         onnet_mou_7  0.174269 -0.009012
# 8         onnet_mou_8  0.167835  0.004004
# 11       offnet_mou_8  0.164774  0.037909
# 104  total_rech_amt_8  0.158594  0.178136
# 103  total_rech_amt_7  0.157934  0.168488
# 37   std_og_t2m_mou_7  0.157783 -0.011355
# 34   std_og_t2t_mou_7  0.148386 -0.025732
# 9        offnet_mou_6  0.147647  0.018211
# 38   std_og_t2m_mou_8  0.142454  0.000248
# 134    Average_amount  0.142360  0.153747
# 35   std_og_t2t_mou_8  0.141553 -0.014168
# 6         onnet_mou_6  0.139690 -0.016998
# 5              arpu_8  0.134706  0.151844
# 4              arpu_7  0.133008  0.143280
# ...

# %%
# %matplotlib inline
fig = plt.figure(figsize = (16,10))
plt.scatter(pcs_df.PC1, pcs_df.PC2)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
for i, txt in enumerate(pcs_df.Feature):
    plt.annotate(txt, (pcs_df.PC1[i],pcs_df.PC2[i]))
plt.tight_layout()
plt.show()

# %%
pca.explained_variance_ratio_
# Out:
# array([  2.49048433e-01,   1.69607016e-01,   1.08660709e-01,
#          7.11631200e-02,   6.10920267e-02,   5.52394034e-02,
#          4.68318008e-02,   3.29958999e-02,   2.58651397e-02,
#          2.23963368e-02,   1.65283316e-02,   1.45282560e-02,
#          1.28034154e-02,   1.21818545e-02,   1.13445354e-02,
#          8.94195880e-03,   7.63339758e-03,   6.93585166e-03,
#          6.64853826e-03,   5.19492441e-03,   4.89451895e-03,
#          4.61035567e-03,   4.25950551e-03,   3.90663328e-03,
#          3.30568816e-03,   2.84684150e-03,   2.67589575e-03,
#          2.65620915e-03,   2.20644859e-03,   2.20213265e-03,
#          1.92965931e-03,   1.69711356e-03,   1.61279849e-03,
#          1.45320241e-03,   1.22198192e-03,   1.03090594e-03,
#          9.57980361e-04,   8.92576492e-04,   8.45093323e-04,
#          8.08002540e-04,   7.40618734e-04,   6.95801895e-04,
#          6.75593335e-04,   5.95772016e-04,   5.67564302e-04,
# ...

# %%
#Making the screeplot - plotting the cumulative variance against the number of components
# %matplotlib inline
fig = plt.figure(figsize = (12,8))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
#Using incremental PCA for efficiency - saves a lot of time on larger datasets let's take 30 components
from sklearn.decomposition import IncrementalPCA
pca_final = IncrementalPCA(n_components=30)

# %%
df_train_pca = pca_final.fit_transform(X_train)
df_train_pca.shape
# Out:
# (21007, 30)

# %%
#creating correlation matrix for the principal components
corrmat = np.corrcoef(df_train_pca.transpose())

# %%
#plotting the correlation matrix
# %matplotlib inline
plt.figure(figsize = (20,10))
sns.heatmap(corrmat,annot = True)

# %%
corrmat_nodiag = corrmat - np.diagflat(corrmat.diagonal())
print(corrmat_nodiag.max())
print(corrmat_nodiag.min())
# Out:
# 0.00900566621716
# -0.00476309556502

# %%
#Applying selected components to the test data - 30 components
df_test_pca = pca_final.transform(X_test)
df_test_pca.shape
# Out:
# (9004, 30)

# %%
#Training the model on the train data
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

learner_pca = LogisticRegression()
model_pca = learner_pca.fit(df_train_pca,y_train)

# %%
#Making prediction on the test data
pred_probs_test = model_pca.predict_proba(df_test_pca)[:,1]
"{:2.2}".format(metrics.roc_auc_score(y_test, pred_probs_test))
# Out:
# '0.89'

# %%
#Now consider only 20 components
from sklearn.decomposition import IncrementalPCA
pca_final2 = IncrementalPCA(n_components=20)

# %%
df_train_pca2 = pca_final2.fit_transform(X_train)
df_train_pca2.shape
# Out:
# (21007, 20)

# %%
#creating correlation matrix for the principal components
corrmat = np.corrcoef(df_train_pca2.transpose())

# %%
#plotting the correlation matrix
# %matplotlib inline
plt.figure(figsize = (20,10))
sns.heatmap(corrmat,annot = True)

# %%
corrmat_nodiag = corrmat - np.diagflat(corrmat.diagonal())
print(corrmat_nodiag.max())
print(corrmat_nodiag.min())
# Out:
# 0.00307813623631
# -0.0063841758336

# %%
#Applying selected components to the test data - 20 components
df_test_pca2 = pca_final2.transform(X_test)
df_test_pca2.shape
# Out:
# (9004, 20)

# %%
#Training the model on the train data
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

learner_pca2 = LogisticRegression()
model_pca2 = learner_pca2.fit(df_train_pca2,y_train)
#Making prediction on the test data
pred_probs_test2 = model_pca2.predict_proba(df_test_pca2)[:,1]
"{:2.2}".format(metrics.roc_auc_score(y_test, pred_probs_test2))
# Out:
# '0.87'

# %%
pca_final3 = IncrementalPCA(n_components=10)

# %%
df_train_pca3 = pca_final3.fit_transform(X_train)
df_train_pca3.shape
# Out:
# (21007, 10)

# %%
#creating correlation matrix for the principal components
corrmat = np.corrcoef(df_train_pca3.transpose())

# %%
#plotting the correlation matrix
# %matplotlib inline
plt.figure(figsize = (20,10))
sns.heatmap(corrmat,annot = True)

# %%
#Applying selected components to the test data - 20 components
df_test_pca3 = pca_final3.transform(X_test)
df_test_pca3.shape
# Out:
# (9004, 10)

# %%
#Training the model on the train data

learner_pca3 = LogisticRegression()
model_pca3 = learner_pca3.fit(df_train_pca3,y_train)
#Making prediction on the test data
pred_probs_test3 = model_pca3.predict_proba(df_test_pca3)[:,1]
"{:2.2}".format(metrics.roc_auc_score(y_test, pred_probs_test3))
# Out:
# '0.86'

# %%
#Now consider only 5 components
from sklearn.decomposition import IncrementalPCA
pca_final4 = IncrementalPCA(n_components=5)

# %%
df_train_pca4 = pca_final4.fit_transform(X_train)
df_train_pca4.shape
# Out:
# (21007, 5)

# %%
#creating correlation matrix for the principal components
corrmat = np.corrcoef(df_train_pca4.transpose())

# %%
#plotting the correlation matrix
# %matplotlib inline
plt.figure(figsize = (20,10))
sns.heatmap(corrmat,annot = True)

# %%
#Applying selected components to the test data - 20 components
df_test_pca4 = pca_final4.transform(X_test)
df_test_pca4.shape
# Out:
# (9004, 5)

# %%
#Training the model on the train data

learner_pca4 = LogisticRegression()
model_pca4 = learner_pca3.fit(df_train_pca4,y_train)
#Making prediction on the test data
pred_probs_test4 = model_pca4.predict_proba(df_test_pca4)[:,1]
"{:2.2}".format(metrics.roc_auc_score(y_test, pred_probs_test4))
# Out:
# '0.75'

# %% [markdown]
# From above we can see that having 10 components would help us have more roc_auc_score hence learner_pca3 is the model that can be used than all the other models.

# %% [markdown]
# From pca components we can see the strong indicators of churn
# total_og_mou_7
# total_og_mou_8
# offnet_mou_7
# onnet_mou_8
# offnet_mou_8
# are the strong affectors of churn

# %% [markdown]
# When the outgoing calls in 7th and 8th month,offnet in 7th and 8th,and onnet in 8th month are very less or are not done, then we can predict that the customer can churn

# %% [markdown]
# Recommendations to prevent churn:

# %% [markdown]
# 1.To do marketing in 8th and 9th months, when we see the values of columns(indicators) are zero(0)
# 2.To gives discounts and offers to the people who are about to churn(in 9th month)
